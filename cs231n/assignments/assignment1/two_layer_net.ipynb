# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME = 'cs231n/assignments/assignment1/cs231n/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cp -r $FOLDERNAME ../../
# %cd ../../
# %cd cs231n/datasets/
# !bash get_datasets.sh
# %cd ../../
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content
# /content/cs231n/datasets
# --2020-07-26 00:12:34--  http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  15.8MB/s    in 12s
#
# 2020-07-26 00:12:46 (14.1 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# /content

# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7963408538435033e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 1.276034e-10
# W2 max relative error: 3.440708e-09
# b1 max relative error: 1.555471e-09
# W1 max relative error: 3.561318e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.02.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149668147307666

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302959
# iteration 100 / 1000: loss 2.302495
# iteration 200 / 1000: loss 2.296892
# iteration 300 / 1000: loss 2.259975
# iteration 400 / 1000: loss 2.209912
# iteration 500 / 1000: loss 2.107752
# iteration 600 / 1000: loss 2.084645
# iteration 700 / 1000: loss 2.030490
# iteration 800 / 1000: loss 2.064425
# iteration 900 / 1000: loss 1.982448
# Validation accuracy:  0.291

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (52% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$

# %%
from operator import itemgetter
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

learning_rates = np.linspace(1e-4, 1e-5, 5)
regularization_strengths = np.linspace(0.2, 0.3, 3)
hidden_sizes = np.linspace(30, 70, 5, dtype=np.int)
num_iters = np.linspace(1000, 1400, 3, dtype=np.int)
                                  

best = []
input_size = 32 * 32 * 3
num_classes = 10
it = 0
results = {}
for lr in learning_rates:
  for rs in regularization_strengths:
    for hs in hidden_sizes:
      for ni in num_iters:
        it += 1
        print(it)
        hidden_size = hs
        net = TwoLayerNet(input_size, hidden_size, num_classes)
        stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=ni, batch_size=200,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=rs, verbose=True)
        y_train_pred = net.predict(X_train)
        y_val_pred = net.predict(X_val)
        train_accuracy = np.mean((y_train == y_train_pred))
        val_accuracy = np.mean((y_val == y_val_pred))
        results[lr, rs, hs, ni] = (train_accuracy, val_accuracy)
        best.append((net, val_accuracy))
    
for lr, rs, hs, ni  in sorted(results):
    train_acc, val_acc = results[(lr, rs, hs, ni)]
    print('lr %e rs %e hs %d ni %d train acc: %f val acc: %f' % (
                ls, rs, hs, ni, train_acc, val_acc))
(best_net, best_val) = max(best, key=lambda x:x[1][1])

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# 1
# iteration 0 / 1000: loss 2.302758
# iteration 100 / 1000: loss 2.302458
# iteration 200 / 1000: loss 2.298824
# iteration 300 / 1000: loss 2.269385
# iteration 400 / 1000: loss 2.174086
# iteration 500 / 1000: loss 2.156816
# iteration 600 / 1000: loss 2.087418
# iteration 700 / 1000: loss 2.040751
# iteration 800 / 1000: loss 2.048084
# iteration 900 / 1000: loss 2.008897
# 2
# iteration 0 / 1200: loss 2.302775
# iteration 100 / 1200: loss 2.302583
# iteration 200 / 1200: loss 2.300518
# iteration 300 / 1200: loss 2.279795
# iteration 400 / 1200: loss 2.233687
# iteration 500 / 1200: loss 2.168194
# iteration 600 / 1200: loss 2.079173
# iteration 700 / 1200: loss 2.025176
# iteration 800 / 1200: loss 1.999584
# iteration 900 / 1200: loss 1.985071
# iteration 1000 / 1200: loss 1.965152
# iteration 1100 / 1200: loss 1.942082
# 3
# iteration 0 / 1400: loss 2.302784
# iteration 100 / 1400: loss 2.302524
# iteration 200 / 1400: loss 2.299918
# iteration 300 / 1400: loss 2.281431
# iteration 400 / 1400: loss 2.194305
# iteration 500 / 1400: loss 2.166161
# iteration 600 / 1400: loss 2.036190
# iteration 700 / 1400: loss 2.069406
# iteration 800 / 1400: loss 2.086878
# iteration 900 / 1400: loss 2.038423
# iteration 1000 / 1400: loss 1.977008
# iteration 1100 / 1400: loss 1.969908
# iteration 1200 / 1400: loss 1.849133
# iteration 1300 / 1400: loss 1.881273
# 4
# iteration 0 / 1000: loss 2.302822
# iteration 100 / 1000: loss 2.302442
# iteration 200 / 1000: loss 2.298327
# iteration 300 / 1000: loss 2.257623
# iteration 400 / 1000: loss 2.198872
# iteration 500 / 1000: loss 2.137390
# iteration 600 / 1000: loss 2.115285
# iteration 700 / 1000: loss 2.038241
# iteration 800 / 1000: loss 1.967341
# iteration 900 / 1000: loss 1.986259
# 5
# iteration 0 / 1200: loss 2.302833
# iteration 100 / 1200: loss 2.302466
# iteration 200 / 1200: loss 2.299952
# iteration 300 / 1200: loss 2.262429
# iteration 400 / 1200: loss 2.210652
# iteration 500 / 1200: loss 2.182066
# iteration 600 / 1200: loss 2.055660
# iteration 700 / 1200: loss 2.038084
# iteration 800 / 1200: loss 2.011097
# iteration 900 / 1200: loss 1.974212
# iteration 1000 / 1200: loss 1.964615
# iteration 1100 / 1200: loss 1.930153
# 6
# iteration 0 / 1400: loss 2.302833
# iteration 100 / 1400: loss 2.302548
# iteration 200 / 1400: loss 2.299946
# iteration 300 / 1400: loss 2.280725
# iteration 400 / 1400: loss 2.221210
# iteration 500 / 1400: loss 2.153059
# iteration 600 / 1400: loss 2.089846
# iteration 700 / 1400: loss 2.017056
# iteration 800 / 1400: loss 1.931494
# iteration 900 / 1400: loss 1.953742
# iteration 1000 / 1400: loss 1.973793
# iteration 1100 / 1400: loss 1.985426
# iteration 1200 / 1400: loss 1.879268
# iteration 1300 / 1400: loss 1.888313
# 7
# iteration 0 / 1000: loss 2.302891
# iteration 100 / 1000: loss 2.302298
# iteration 200 / 1000: loss 2.298408
# iteration 300 / 1000: loss 2.267493
# iteration 400 / 1000: loss 2.198676
# iteration 500 / 1000: loss 2.092173
# iteration 600 / 1000: loss 2.122638
# iteration 700 / 1000: loss 1.997189
# iteration 800 / 1000: loss 1.982606
# iteration 900 / 1000: loss 2.007963
# 8
# iteration 0 / 1200: loss 2.302876
# iteration 100 / 1200: loss 2.302444
# iteration 200 / 1200: loss 2.297665
# iteration 300 / 1200: loss 2.267940
# iteration 400 / 1200: loss 2.213655
# iteration 500 / 1200: loss 2.136991
# iteration 600 / 1200: loss 2.031402
# iteration 700 / 1200: loss 2.025418
# iteration 800 / 1200: loss 1.974227
# iteration 900 / 1200: loss 1.960151
# iteration 1000 / 1200: loss 1.939225
# iteration 1100 / 1200: loss 2.003266
# 9
# iteration 0 / 1400: loss 2.302927
# iteration 100 / 1400: loss 2.302563
# iteration 200 / 1400: loss 2.298543
# iteration 300 / 1400: loss 2.276760
# iteration 400 / 1400: loss 2.220203
# iteration 500 / 1400: loss 2.180069
# iteration 600 / 1400: loss 2.104266
# iteration 700 / 1400: loss 2.029751
# iteration 800 / 1400: loss 2.017341
# iteration 900 / 1400: loss 2.019827
# iteration 1000 / 1400: loss 1.906075
# iteration 1100 / 1400: loss 1.829258
# iteration 1200 / 1400: loss 1.953897
# iteration 1300 / 1400: loss 1.933947
# 10
# iteration 0 / 1000: loss 2.302972
# iteration 100 / 1000: loss 2.302487
# iteration 200 / 1000: loss 2.298756
# iteration 300 / 1000: loss 2.283442
# iteration 400 / 1000: loss 2.183136
# iteration 500 / 1000: loss 2.136627
# iteration 600 / 1000: loss 2.148655
# iteration 700 / 1000: loss 2.095679
# iteration 800 / 1000: loss 1.990174
# iteration 900 / 1000: loss 1.990722
# 11
# iteration 0 / 1200: loss 2.302993
# iteration 100 / 1200: loss 2.302497
# iteration 200 / 1200: loss 2.297527
# iteration 300 / 1200: loss 2.248555
# iteration 400 / 1200: loss 2.221991
# iteration 500 / 1200: loss 2.120937
# iteration 600 / 1200: loss 2.114900
# iteration 700 / 1200: loss 2.092884
# iteration 800 / 1200: loss 2.037793
# iteration 900 / 1200: loss 2.007703
# iteration 1000 / 1200: loss 1.920330
# iteration 1100 / 1200: loss 1.936896
# 12
# iteration 0 / 1400: loss 2.302924
# iteration 100 / 1400: loss 2.302377
# iteration 200 / 1400: loss 2.297480
# iteration 300 / 1400: loss 2.269705
# iteration 400 / 1400: loss 2.192610
# iteration 500 / 1400: loss 2.162428
# iteration 600 / 1400: loss 2.095462
# iteration 700 / 1400: loss 1.957253
# iteration 800 / 1400: loss 2.000050
# iteration 900 / 1400: loss 1.984197
# iteration 1000 / 1400: loss 1.923207
# iteration 1100 / 1400: loss 1.994883
# iteration 1200 / 1400: loss 1.971962
# iteration 1300 / 1400: loss 1.874130
# 13
# iteration 0 / 1000: loss 2.302972
# iteration 100 / 1000: loss 2.302274
# iteration 200 / 1000: loss 2.290663
# iteration 300 / 1000: loss 2.247876
# iteration 400 / 1000: loss 2.188723
# iteration 500 / 1000: loss 2.098741
# iteration 600 / 1000: loss 2.046649
# iteration 700 / 1000: loss 2.051901
# iteration 800 / 1000: loss 1.991119
# iteration 900 / 1000: loss 1.944373
# 14
# iteration 0 / 1200: loss 2.303003
# iteration 100 / 1200: loss 2.302475
# iteration 200 / 1200: loss 2.298218
# iteration 300 / 1200: loss 2.253027
# iteration 400 / 1200: loss 2.195129
# iteration 500 / 1200: loss 2.120214
# iteration 600 / 1200: loss 2.102236
# iteration 700 / 1200: loss 2.011474
# iteration 800 / 1200: loss 1.957832
# iteration 900 / 1200: loss 1.998834
# iteration 1000 / 1200: loss 1.913804
# iteration 1100 / 1200: loss 1.868610
# 15
# iteration 0 / 1400: loss 2.303018
# iteration 100 / 1400: loss 2.302568
# iteration 200 / 1400: loss 2.298427
# iteration 300 / 1400: loss 2.260729
# iteration 400 / 1400: loss 2.187711
# iteration 500 / 1400: loss 2.089230
# iteration 600 / 1400: loss 2.086098
# iteration 700 / 1400: loss 2.059014
# iteration 800 / 1400: loss 2.075601
# iteration 900 / 1400: loss 1.986046
# iteration 1000 / 1400: loss 1.932094
# iteration 1100 / 1400: loss 1.907790
# iteration 1200 / 1400: loss 1.792857
# iteration 1300 / 1400: loss 1.862012
# 16
# iteration 0 / 1000: loss 2.302810
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.300255
# iteration 300 / 1000: loss 2.276355
# iteration 400 / 1000: loss 2.193011
# iteration 500 / 1000: loss 2.113003
# iteration 600 / 1000: loss 2.058400
# iteration 700 / 1000: loss 2.108574
# iteration 800 / 1000: loss 2.018175
# iteration 900 / 1000: loss 1.923151
# 17
# iteration 0 / 1200: loss 2.302815
# iteration 100 / 1200: loss 2.302335
# iteration 200 / 1200: loss 2.298003
# iteration 300 / 1200: loss 2.269158
# iteration 400 / 1200: loss 2.170454
# iteration 500 / 1200: loss 2.186526
# iteration 600 / 1200: loss 2.062033
# iteration 700 / 1200: loss 2.068511
# iteration 800 / 1200: loss 1.995766
# iteration 900 / 1200: loss 1.934784
# iteration 1000 / 1200: loss 2.043110
# iteration 1100 / 1200: loss 1.961449
# 18
# iteration 0 / 1400: loss 2.302807
# iteration 100 / 1400: loss 2.302501
# iteration 200 / 1400: loss 2.299772
# iteration 300 / 1400: loss 2.272373
# iteration 400 / 1400: loss 2.212263
# iteration 500 / 1400: loss 2.153729
# iteration 600 / 1400: loss 2.140150
# iteration 700 / 1400: loss 2.068928
# iteration 800 / 1400: loss 2.048665
# iteration 900 / 1400: loss 1.980421
# iteration 1000 / 1400: loss 1.990332
# iteration 1100 / 1400: loss 2.079656
# iteration 1200 / 1400: loss 1.857053
# iteration 1300 / 1400: loss 1.907816
# 19
# iteration 0 / 1000: loss 2.302910
# iteration 100 / 1000: loss 2.302635
# iteration 200 / 1000: loss 2.300714
# iteration 300 / 1000: loss 2.279735
# iteration 400 / 1000: loss 2.215917
# iteration 500 / 1000: loss 2.159483
# iteration 600 / 1000: loss 2.052040
# iteration 700 / 1000: loss 2.028853
# iteration 800 / 1000: loss 1.995946
# iteration 900 / 1000: loss 1.985456
# 20
# iteration 0 / 1200: loss 2.302885
# iteration 100 / 1200: loss 2.302545
# iteration 200 / 1200: loss 2.297728
# iteration 300 / 1200: loss 2.283307
# iteration 400 / 1200: loss 2.189085
# iteration 500 / 1200: loss 2.120553
# iteration 600 / 1200: loss 2.075349
# iteration 700 / 1200: loss 2.142519
# iteration 800 / 1200: loss 2.126778
# iteration 900 / 1200: loss 2.003255
# iteration 1000 / 1200: loss 1.995865
# iteration 1100 / 1200: loss 1.857170
# 21
# iteration 0 / 1400: loss 2.302877
# iteration 100 / 1400: loss 2.302526
# iteration 200 / 1400: loss 2.298607
# iteration 300 / 1400: loss 2.265234
# iteration 400 / 1400: loss 2.194255
# iteration 500 / 1400: loss 2.135708
# iteration 600 / 1400: loss 2.010488
# iteration 700 / 1400: loss 2.104306
# iteration 800 / 1400: loss 1.957871
# iteration 900 / 1400: loss 1.930983
# iteration 1000 / 1400: loss 1.954676
# iteration 1100 / 1400: loss 1.932432
# iteration 1200 / 1400: loss 1.929407
# iteration 1300 / 1400: loss 1.823375
# 22
# iteration 0 / 1000: loss 2.302955
# iteration 100 / 1000: loss 2.302483
# iteration 200 / 1000: loss 2.296947
# iteration 300 / 1000: loss 2.260768
# iteration 400 / 1000: loss 2.168027
# iteration 500 / 1000: loss 2.150320
# iteration 600 / 1000: loss 2.107765
# iteration 700 / 1000: loss 2.032386
# iteration 800 / 1000: loss 2.032551
# iteration 900 / 1000: loss 2.004263
# 23
# iteration 0 / 1200: loss 2.302961
# iteration 100 / 1200: loss 2.302332
# iteration 200 / 1200: loss 2.297036
# iteration 300 / 1200: loss 2.243780
# iteration 400 / 1200: loss 2.159158
# iteration 500 / 1200: loss 2.074762
# iteration 600 / 1200: loss 2.121093
# iteration 700 / 1200: loss 2.015570
# iteration 800 / 1200: loss 2.017293
# iteration 900 / 1200: loss 1.926872
# iteration 1000 / 1200: loss 1.976546
# iteration 1100 / 1200: loss 2.038106
# 24
# iteration 0 / 1400: loss 2.302966
# iteration 100 / 1400: loss 2.302489
# iteration 200 / 1400: loss 2.298595
# iteration 300 / 1400: loss 2.277535
# iteration 400 / 1400: loss 2.192668
# iteration 500 / 1400: loss 2.092548
# iteration 600 / 1400: loss 2.114648
# iteration 700 / 1400: loss 2.020423
# iteration 800 / 1400: loss 2.026042
# iteration 900 / 1400: loss 1.966442
# iteration 1000 / 1400: loss 1.962407
# iteration 1100 / 1400: loss 1.910326
# iteration 1200 / 1400: loss 1.937221
# iteration 1300 / 1400: loss 1.909870
# 25
# iteration 0 / 1000: loss 2.303038
# iteration 100 / 1000: loss 2.302345
# iteration 200 / 1000: loss 2.297452
# iteration 300 / 1000: loss 2.258919
# iteration 400 / 1000: loss 2.180641
# iteration 500 / 1000: loss 2.085267
# iteration 600 / 1000: loss 2.141746
# iteration 700 / 1000: loss 2.054690
# iteration 800 / 1000: loss 2.104435
# iteration 900 / 1000: loss 1.943747
# 26
# iteration 0 / 1200: loss 2.303054
# iteration 100 / 1200: loss 2.302399
# iteration 200 / 1200: loss 2.295694
# iteration 300 / 1200: loss 2.256330
# iteration 400 / 1200: loss 2.206414
# iteration 500 / 1200: loss 2.098743
# iteration 600 / 1200: loss 2.059646
# iteration 700 / 1200: loss 1.976957
# iteration 800 / 1200: loss 2.008270
# iteration 900 / 1200: loss 1.993094
# iteration 1000 / 1200: loss 1.967986
# iteration 1100 / 1200: loss 2.031929
# 27
# iteration 0 / 1400: loss 2.303075
# iteration 100 / 1400: loss 2.302547
# iteration 200 / 1400: loss 2.298126
# iteration 300 / 1400: loss 2.255669
# iteration 400 / 1400: loss 2.159938
# iteration 500 / 1400: loss 2.144095
# iteration 600 / 1400: loss 2.070992
# iteration 700 / 1400: loss 2.022459
# iteration 800 / 1400: loss 2.007965
# iteration 900 / 1400: loss 1.991173
# iteration 1000 / 1400: loss 1.847083
# iteration 1100 / 1400: loss 1.961600
# iteration 1200 / 1400: loss 1.959020
# iteration 1300 / 1400: loss 1.918430
# 28
# iteration 0 / 1000: loss 2.303127
# iteration 100 / 1000: loss 2.302537
# iteration 200 / 1000: loss 2.296345
# iteration 300 / 1000: loss 2.258151
# iteration 400 / 1000: loss 2.188163
# iteration 500 / 1000: loss 2.092077
# iteration 600 / 1000: loss 2.068571
# iteration 700 / 1000: loss 2.037572
# iteration 800 / 1000: loss 2.001921
# iteration 900 / 1000: loss 1.981061
# 29
# iteration 0 / 1200: loss 2.303101
# iteration 100 / 1200: loss 2.302585
# iteration 200 / 1200: loss 2.295646
# iteration 300 / 1200: loss 2.251476
# iteration 400 / 1200: loss 2.162912
# iteration 500 / 1200: loss 2.092566
# iteration 600 / 1200: loss 2.015902
# iteration 700 / 1200: loss 2.003334
# iteration 800 / 1200: loss 2.006199
# iteration 900 / 1200: loss 1.999985
# iteration 1000 / 1200: loss 1.953337
# iteration 1100 / 1200: loss 1.885314
# 30
# iteration 0 / 1400: loss 2.303123
# iteration 100 / 1400: loss 2.302241
# iteration 200 / 1400: loss 2.296248
# iteration 300 / 1400: loss 2.249946
# iteration 400 / 1400: loss 2.166017
# iteration 500 / 1400: loss 2.049829
# iteration 600 / 1400: loss 2.106542
# iteration 700 / 1400: loss 2.029115
# iteration 800 / 1400: loss 1.909412
# iteration 900 / 1400: loss 1.987276
# iteration 1000 / 1400: loss 1.912710
# iteration 1100 / 1400: loss 1.932626
# iteration 1200 / 1400: loss 1.940358
# iteration 1300 / 1400: loss 1.855846
# 31
# iteration 0 / 1000: loss 2.302869
# iteration 100 / 1000: loss 2.302613
# iteration 200 / 1000: loss 2.300056
# iteration 300 / 1000: loss 2.277935
# iteration 400 / 1000: loss 2.211118
# iteration 500 / 1000: loss 2.157698
# iteration 600 / 1000: loss 2.077502
# iteration 700 / 1000: loss 2.059997
# iteration 800 / 1000: loss 1.975813
# iteration 900 / 1000: loss 2.024243
# 32
# iteration 0 / 1200: loss 2.302850
# iteration 100 / 1200: loss 2.302516
# iteration 200 / 1200: loss 2.298798
# iteration 300 / 1200: loss 2.275029
# iteration 400 / 1200: loss 2.204987
# iteration 500 / 1200: loss 2.199693
# iteration 600 / 1200: loss 2.151354
# iteration 700 / 1200: loss 2.044450
# iteration 800 / 1200: loss 1.966075
# iteration 900 / 1200: loss 1.990660
# iteration 1000 / 1200: loss 1.924528
# iteration 1100 / 1200: loss 1.990257
# 33
# iteration 0 / 1400: loss 2.302877
# iteration 100 / 1400: loss 2.302515
# iteration 200 / 1400: loss 2.299180
# iteration 300 / 1400: loss 2.272923
# iteration 400 / 1400: loss 2.204939
# iteration 500 / 1400: loss 2.148210
# iteration 600 / 1400: loss 2.062138
# iteration 700 / 1400: loss 2.049655
# iteration 800 / 1400: loss 1.999326
# iteration 900 / 1400: loss 2.040671
# iteration 1000 / 1400: loss 2.024868
# iteration 1100 / 1400: loss 2.034511
# iteration 1200 / 1400: loss 1.941994
# iteration 1300 / 1400: loss 1.876692
# 34
# iteration 0 / 1000: loss 2.302932
# iteration 100 / 1000: loss 2.302509
# iteration 200 / 1000: loss 2.299576
# iteration 300 / 1000: loss 2.269011
# iteration 400 / 1000: loss 2.222017
# iteration 500 / 1000: loss 2.093454
# iteration 600 / 1000: loss 2.030468
# iteration 700 / 1000: loss 2.037479
# iteration 800 / 1000: loss 1.978673
# iteration 900 / 1000: loss 1.991213
# 35
# iteration 0 / 1200: loss 2.302952
# iteration 100 / 1200: loss 2.302578
# iteration 200 / 1200: loss 2.300131
# iteration 300 / 1200: loss 2.272669
# iteration 400 / 1200: loss 2.193661
# iteration 500 / 1200: loss 2.132822
# iteration 600 / 1200: loss 2.065546
# iteration 700 / 1200: loss 2.079358
# iteration 800 / 1200: loss 2.019244
# iteration 900 / 1200: loss 2.036017
# iteration 1000 / 1200: loss 1.953467
# iteration 1100 / 1200: loss 1.894494
# 36
# iteration 0 / 1400: loss 2.302965
# iteration 100 / 1400: loss 2.302626
# iteration 200 / 1400: loss 2.299400
# iteration 300 / 1400: loss 2.269623
# iteration 400 / 1400: loss 2.207696
# iteration 500 / 1400: loss 2.177348
# iteration 600 / 1400: loss 2.072531
# iteration 700 / 1400: loss 2.057037
# iteration 800 / 1400: loss 1.962515
# iteration 900 / 1400: loss 1.980483
# iteration 1000 / 1400: loss 2.033438
# iteration 1100 / 1400: loss 1.915446
# iteration 1200 / 1400: loss 1.889247
# iteration 1300 / 1400: loss 1.827643
# 37
# iteration 0 / 1000: loss 2.303053
# iteration 100 / 1000: loss 2.302405
# iteration 200 / 1000: loss 2.296265
# iteration 300 / 1000: loss 2.249420
# iteration 400 / 1000: loss 2.196934
# iteration 500 / 1000: loss 2.084572
# iteration 600 / 1000: loss 2.090815
# iteration 700 / 1000: loss 2.073401
# iteration 800 / 1000: loss 1.994403
# iteration 900 / 1000: loss 2.073105
# 38
# iteration 0 / 1200: loss 2.303030
# iteration 100 / 1200: loss 2.302475
# iteration 200 / 1200: loss 2.298017
# iteration 300 / 1200: loss 2.242265
# iteration 400 / 1200: loss 2.224034
# iteration 500 / 1200: loss 2.084213
# iteration 600 / 1200: loss 2.126281
# iteration 700 / 1200: loss 2.017721
# iteration 800 / 1200: loss 2.061238
# iteration 900 / 1200: loss 2.080172
# iteration 1000 / 1200: loss 1.972966
# iteration 1100 / 1200: loss 1.932615
# 39
# iteration 0 / 1400: loss 2.303052
# iteration 100 / 1400: loss 2.302489
# iteration 200 / 1400: loss 2.297237
# iteration 300 / 1400: loss 2.262981
# iteration 400 / 1400: loss 2.188618
# iteration 500 / 1400: loss 2.125549
# iteration 600 / 1400: loss 2.072798
# iteration 700 / 1400: loss 1.969113
# iteration 800 / 1400: loss 2.109851
# iteration 900 / 1400: loss 1.986975
# iteration 1000 / 1400: loss 1.893928
# iteration 1100 / 1400: loss 1.938178
# iteration 1200 / 1400: loss 1.913593
# iteration 1300 / 1400: loss 1.896239
# 40
# iteration 0 / 1000: loss 2.303169
# iteration 100 / 1000: loss 2.302653
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.264580
# iteration 400 / 1000: loss 2.174667
# iteration 500 / 1000: loss 2.158096
# iteration 600 / 1000: loss 2.071336
# iteration 700 / 1000: loss 1.947005
# iteration 800 / 1000: loss 1.950982
# iteration 900 / 1000: loss 2.011493
# 41
# iteration 0 / 1200: loss 2.303167
# iteration 100 / 1200: loss 2.302657
# iteration 200 / 1200: loss 2.295628
# iteration 300 / 1200: loss 2.278932
# iteration 400 / 1200: loss 2.153099
# iteration 500 / 1200: loss 2.069514
# iteration 600 / 1200: loss 2.057600
# iteration 700 / 1200: loss 2.033342
# iteration 800 / 1200: loss 2.050748
# iteration 900 / 1200: loss 1.929929
# iteration 1000 / 1200: loss 1.959362
# iteration 1100 / 1200: loss 1.895060
# 42
# iteration 0 / 1400: loss 2.303154
# iteration 100 / 1400: loss 2.302526
# iteration 200 / 1400: loss 2.295505
# iteration 300 / 1400: loss 2.264518
# iteration 400 / 1400: loss 2.183320
# iteration 500 / 1400: loss 2.126730
# iteration 600 / 1400: loss 2.135378
# iteration 700 / 1400: loss 2.086075
# iteration 800 / 1400: loss 2.038677
# iteration 900 / 1400: loss 1.940356
# iteration 1000 / 1400: loss 2.005337
# iteration 1100 / 1400: loss 1.913371
# iteration 1200 / 1400: loss 1.906752
# iteration 1300 / 1400: loss 1.867123
# 43
# iteration 0 / 1000: loss 2.303223
# iteration 100 / 1000: loss 2.302685
# iteration 200 / 1000: loss 2.297587
# iteration 300 / 1000: loss 2.257482
# iteration 400 / 1000: loss 2.207045
# iteration 500 / 1000: loss 2.101118
# iteration 600 / 1000: loss 2.063800
# iteration 700 / 1000: loss 2.013004
# iteration 800 / 1000: loss 1.958178
# iteration 900 / 1000: loss 1.980917
# 44
# iteration 0 / 1200: loss 2.303206
# iteration 100 / 1200: loss 2.302570
# iteration 200 / 1200: loss 2.295510
# iteration 300 / 1200: loss 2.227376
# iteration 400 / 1200: loss 2.174416
# iteration 500 / 1200: loss 2.059808
# iteration 600 / 1200: loss 2.108614
# iteration 700 / 1200: loss 2.056421
# iteration 800 / 1200: loss 2.052130
# iteration 900 / 1200: loss 1.999854
# iteration 1000 / 1200: loss 1.921603
# iteration 1100 / 1200: loss 1.951865
# 45
# iteration 0 / 1400: loss 2.303262
# iteration 100 / 1400: loss 2.302835
# iteration 200 / 1400: loss 2.299106
# iteration 300 / 1400: loss 2.270753
# iteration 400 / 1400: loss 2.182671
# iteration 500 / 1400: loss 2.092926
# iteration 600 / 1400: loss 2.068634
# iteration 700 / 1400: loss 2.038647
# iteration 800 / 1400: loss 1.964009
# iteration 900 / 1400: loss 1.946209
# iteration 1000 / 1400: loss 1.915675
# iteration 1100 / 1400: loss 1.947306
# iteration 1200 / 1400: loss 1.983237
# iteration 1300 / 1400: loss 1.940309
# 46
# iteration 0 / 1000: loss 2.302768
# iteration 100 / 1000: loss 2.302574
# iteration 200 / 1000: loss 2.301726
# iteration 300 / 1000: loss 2.296294
# iteration 400 / 1000: loss 2.258279
# iteration 500 / 1000: loss 2.215665
# iteration 600 / 1000: loss 2.122158
# iteration 700 / 1000: loss 2.161936
# iteration 800 / 1000: loss 2.068418
# iteration 900 / 1000: loss 2.030765
# 47
# iteration 0 / 1200: loss 2.302770
# iteration 100 / 1200: loss 2.302604
# iteration 200 / 1200: loss 2.301371
# iteration 300 / 1200: loss 2.293720
# iteration 400 / 1200: loss 2.267612
# iteration 500 / 1200: loss 2.185135
# iteration 600 / 1200: loss 2.171152
# iteration 700 / 1200: loss 2.149578
# iteration 800 / 1200: loss 2.063223
# iteration 900 / 1200: loss 2.052099
# iteration 1000 / 1200: loss 1.941820
# iteration 1100 / 1200: loss 2.050304
# 48
# iteration 0 / 1400: loss 2.302751
# iteration 100 / 1400: loss 2.302622
# iteration 200 / 1400: loss 2.301663
# iteration 300 / 1400: loss 2.296090
# iteration 400 / 1400: loss 2.267487
# iteration 500 / 1400: loss 2.204801
# iteration 600 / 1400: loss 2.206354
# iteration 700 / 1400: loss 2.140090
# iteration 800 / 1400: loss 2.077344
# iteration 900 / 1400: loss 2.085977
# iteration 1000 / 1400: loss 1.995895
# iteration 1100 / 1400: loss 1.957342
# iteration 1200 / 1400: loss 1.949311
# iteration 1300 / 1400: loss 2.000007
# 49
# iteration 0 / 1000: loss 2.302852
# iteration 100 / 1000: loss 2.302636
# iteration 200 / 1000: loss 2.301545
# iteration 300 / 1000: loss 2.295745
# iteration 400 / 1000: loss 2.264513
# iteration 500 / 1000: loss 2.201603
# iteration 600 / 1000: loss 2.137030
# iteration 700 / 1000: loss 2.159142
# iteration 800 / 1000: loss 2.101205
# iteration 900 / 1000: loss 2.055896
# 50
# iteration 0 / 1200: loss 2.302846
# iteration 100 / 1200: loss 2.302695
# iteration 200 / 1200: loss 2.302257
# iteration 300 / 1200: loss 2.300375
# iteration 400 / 1200: loss 2.280730
# iteration 500 / 1200: loss 2.238882
# iteration 600 / 1200: loss 2.153120
# iteration 700 / 1200: loss 2.131911
# iteration 800 / 1200: loss 2.035662
# iteration 900 / 1200: loss 2.132100
# iteration 1000 / 1200: loss 2.030412
# iteration 1100 / 1200: loss 2.021502
# 51
# iteration 0 / 1400: loss 2.302849
# iteration 100 / 1400: loss 2.302701
# iteration 200 / 1400: loss 2.301874
# iteration 300 / 1400: loss 2.298858
# iteration 400 / 1400: loss 2.269990
# iteration 500 / 1400: loss 2.214897
# iteration 600 / 1400: loss 2.175567
# iteration 700 / 1400: loss 2.153961
# iteration 800 / 1400: loss 2.093673
# iteration 900 / 1400: loss 2.032512
# iteration 1000 / 1400: loss 2.076140
# iteration 1100 / 1400: loss 2.047641
# iteration 1200 / 1400: loss 1.938737
# iteration 1300 / 1400: loss 1.931607
# 52
# iteration 0 / 1000: loss 2.302896
# iteration 100 / 1000: loss 2.302563
# iteration 200 / 1000: loss 2.300483
# iteration 300 / 1000: loss 2.290851
# iteration 400 / 1000: loss 2.241059
# iteration 500 / 1000: loss 2.187633
# iteration 600 / 1000: loss 2.156916
# iteration 700 / 1000: loss 2.095166
# iteration 800 / 1000: loss 2.067882
# iteration 900 / 1000: loss 2.020801
# 53
# iteration 0 / 1200: loss 2.302880
# iteration 100 / 1200: loss 2.302657
# iteration 200 / 1200: loss 2.301592
# iteration 300 / 1200: loss 2.293248
# iteration 400 / 1200: loss 2.241350
# iteration 500 / 1200: loss 2.231108
# iteration 600 / 1200: loss 2.132791
# iteration 700 / 1200: loss 2.103141
# iteration 800 / 1200: loss 2.040382
# iteration 900 / 1200: loss 2.084356
# iteration 1000 / 1200: loss 2.090718
# iteration 1100 / 1200: loss 1.933377
# 54
# iteration 0 / 1400: loss 2.302880
# iteration 100 / 1400: loss 2.302642
# iteration 200 / 1400: loss 2.301346
# iteration 300 / 1400: loss 2.289810
# iteration 400 / 1400: loss 2.238834
# iteration 500 / 1400: loss 2.215860
# iteration 600 / 1400: loss 2.155147
# iteration 700 / 1400: loss 2.089938
# iteration 800 / 1400: loss 2.056641
# iteration 900 / 1400: loss 1.981906
# iteration 1000 / 1400: loss 1.972381
# iteration 1100 / 1400: loss 2.067346
# iteration 1200 / 1400: loss 1.945177
# iteration 1300 / 1400: loss 1.936613
# 55
# iteration 0 / 1000: loss 2.302941
# iteration 100 / 1000: loss 2.302614
# iteration 200 / 1000: loss 2.300749
# iteration 300 / 1000: loss 2.287904
# iteration 400 / 1000: loss 2.237905
# iteration 500 / 1000: loss 2.204829
# iteration 600 / 1000: loss 2.127371
# iteration 700 / 1000: loss 2.121416
# iteration 800 / 1000: loss 2.063150
# iteration 900 / 1000: loss 2.041143
# 56
# iteration 0 / 1200: loss 2.302948
# iteration 100 / 1200: loss 2.302500
# iteration 200 / 1200: loss 2.300714
# iteration 300 / 1200: loss 2.285475
# iteration 400 / 1200: loss 2.238895
# iteration 500 / 1200: loss 2.193913
# iteration 600 / 1200: loss 2.169157
# iteration 700 / 1200: loss 2.115100
# iteration 800 / 1200: loss 2.036447
# iteration 900 / 1200: loss 2.052815
# iteration 1000 / 1200: loss 2.085291
# iteration 1100 / 1200: loss 1.961721
# 57
# iteration 0 / 1400: loss 2.302938
# iteration 100 / 1400: loss 2.302450
# iteration 200 / 1400: loss 2.300643
# iteration 300 / 1400: loss 2.286233
# iteration 400 / 1400: loss 2.256520
# iteration 500 / 1400: loss 2.217632
# iteration 600 / 1400: loss 2.093311
# iteration 700 / 1400: loss 2.163526
# iteration 800 / 1400: loss 2.011481
# iteration 900 / 1400: loss 2.024529
# iteration 1000 / 1400: loss 1.967429
# iteration 1100 / 1400: loss 1.907351
# iteration 1200 / 1400: loss 1.957461
# iteration 1300 / 1400: loss 1.974861
# 58
# iteration 0 / 1000: loss 2.303031
# iteration 100 / 1000: loss 2.302792
# iteration 200 / 1000: loss 2.300908
# iteration 300 / 1000: loss 2.291817
# iteration 400 / 1000: loss 2.272351
# iteration 500 / 1000: loss 2.239574
# iteration 600 / 1000: loss 2.218695
# iteration 700 / 1000: loss 2.069758
# iteration 800 / 1000: loss 2.076032
# iteration 900 / 1000: loss 2.075726
# 59
# iteration 0 / 1200: loss 2.303022
# iteration 100 / 1200: loss 2.302602
# iteration 200 / 1200: loss 2.301171
# iteration 300 / 1200: loss 2.289840
# iteration 400 / 1200: loss 2.266150
# iteration 500 / 1200: loss 2.188037
# iteration 600 / 1200: loss 2.220642
# iteration 700 / 1200: loss 2.095163
# iteration 800 / 1200: loss 2.067624
# iteration 900 / 1200: loss 2.052236
# iteration 1000 / 1200: loss 1.987834
# iteration 1100 / 1200: loss 2.057540
# 60
# iteration 0 / 1400: loss 2.303020
# iteration 100 / 1400: loss 2.302642
# iteration 200 / 1400: loss 2.300475
# iteration 300 / 1400: loss 2.290672
# iteration 400 / 1400: loss 2.238629
# iteration 500 / 1400: loss 2.169109
# iteration 600 / 1400: loss 2.089106
# iteration 700 / 1400: loss 2.090959
# iteration 800 / 1400: loss 2.085471
# iteration 900 / 1400: loss 2.042635
# iteration 1000 / 1400: loss 2.041971
# iteration 1100 / 1400: loss 1.954272
# iteration 1200 / 1400: loss 1.948661
# iteration 1300 / 1400: loss 2.017632
# 61
# iteration 0 / 1000: loss 2.302800
# iteration 100 / 1000: loss 2.302648
# iteration 200 / 1000: loss 2.301711
# iteration 300 / 1000: loss 2.297855
# iteration 400 / 1000: loss 2.272019
# iteration 500 / 1000: loss 2.209777
# iteration 600 / 1000: loss 2.159769
# iteration 700 / 1000: loss 2.126492
# iteration 800 / 1000: loss 2.077933
# iteration 900 / 1000: loss 1.984154
# 62
# iteration 0 / 1200: loss 2.302831
# iteration 100 / 1200: loss 2.302706
# iteration 200 / 1200: loss 2.302169
# iteration 300 / 1200: loss 2.299071
# iteration 400 / 1200: loss 2.284009
# iteration 500 / 1200: loss 2.218799
# iteration 600 / 1200: loss 2.129325
# iteration 700 / 1200: loss 2.116977
# iteration 800 / 1200: loss 2.063058
# iteration 900 / 1200: loss 2.069214
# iteration 1000 / 1200: loss 2.018812
# iteration 1100 / 1200: loss 2.033731
# 63
# iteration 0 / 1400: loss 2.302797
# iteration 100 / 1400: loss 2.302591
# iteration 200 / 1400: loss 2.301450
# iteration 300 / 1400: loss 2.291686
# iteration 400 / 1400: loss 2.258913
# iteration 500 / 1400: loss 2.198172
# iteration 600 / 1400: loss 2.178386
# iteration 700 / 1400: loss 2.162018
# iteration 800 / 1400: loss 2.077519
# iteration 900 / 1400: loss 2.115812
# iteration 1000 / 1400: loss 2.077063
# iteration 1100 / 1400: loss 2.042639
# iteration 1200 / 1400: loss 2.032395
# iteration 1300 / 1400: loss 2.049659
# 64
# iteration 0 / 1000: loss 2.302891
# iteration 100 / 1000: loss 2.302678
# iteration 200 / 1000: loss 2.301845
# iteration 300 / 1000: loss 2.295420
# iteration 400 / 1000: loss 2.265116
# iteration 500 / 1000: loss 2.226833
# iteration 600 / 1000: loss 2.166050
# iteration 700 / 1000: loss 2.112299
# iteration 800 / 1000: loss 2.133096
# iteration 900 / 1000: loss 2.003109
# 65
# iteration 0 / 1200: loss 2.302898
# iteration 100 / 1200: loss 2.302733
# iteration 200 / 1200: loss 2.301664
# iteration 300 / 1200: loss 2.297637
# iteration 400 / 1200: loss 2.263685
# iteration 500 / 1200: loss 2.254948
# iteration 600 / 1200: loss 2.121360
# iteration 700 / 1200: loss 2.172799
# iteration 800 / 1200: loss 2.095735
# iteration 900 / 1200: loss 2.096704
# iteration 1000 / 1200: loss 2.081270
# iteration 1100 / 1200: loss 1.944488
# 66
# iteration 0 / 1400: loss 2.302916
# iteration 100 / 1400: loss 2.302725
# iteration 200 / 1400: loss 2.302002
# iteration 300 / 1400: loss 2.295272
# iteration 400 / 1400: loss 2.260536
# iteration 500 / 1400: loss 2.216078
# iteration 600 / 1400: loss 2.174166
# iteration 700 / 1400: loss 2.118564
# iteration 800 / 1400: loss 2.096932
# iteration 900 / 1400: loss 2.083214
# iteration 1000 / 1400: loss 2.018216
# iteration 1100 / 1400: loss 2.041583
# iteration 1200 / 1400: loss 1.995023
# iteration 1300 / 1400: loss 1.945618
# 67
# iteration 0 / 1000: loss 2.302985
# iteration 100 / 1000: loss 2.302752
# iteration 200 / 1000: loss 2.301715
# iteration 300 / 1000: loss 2.294404
# iteration 400 / 1000: loss 2.269185
# iteration 500 / 1000: loss 2.230505
# iteration 600 / 1000: loss 2.169655
# iteration 700 / 1000: loss 2.040608
# iteration 800 / 1000: loss 2.159875
# iteration 900 / 1000: loss 2.054494
# 68
# iteration 0 / 1200: loss 2.302967
# iteration 100 / 1200: loss 2.302645
# iteration 200 / 1200: loss 2.301076
# iteration 300 / 1200: loss 2.291443
# iteration 400 / 1200: loss 2.259613
# iteration 500 / 1200: loss 2.170947
# iteration 600 / 1200: loss 2.148156
# iteration 700 / 1200: loss 2.103928
# iteration 800 / 1200: loss 2.121271
# iteration 900 / 1200: loss 2.009459
# iteration 1000 / 1200: loss 1.922529
# iteration 1100 / 1200: loss 1.949777
# 69
# iteration 0 / 1400: loss 2.302952
# iteration 100 / 1400: loss 2.302649
# iteration 200 / 1400: loss 2.300920
# iteration 300 / 1400: loss 2.291180
# iteration 400 / 1400: loss 2.246931
# iteration 500 / 1400: loss 2.188358
# iteration 600 / 1400: loss 2.144941
# iteration 700 / 1400: loss 2.129740
# iteration 800 / 1400: loss 2.074089
# iteration 900 / 1400: loss 2.027520
# iteration 1000 / 1400: loss 2.001061
# iteration 1100 / 1400: loss 2.012065
# iteration 1200 / 1400: loss 2.061822
# iteration 1300 / 1400: loss 2.025411
# 70
# iteration 0 / 1000: loss 2.303052
# iteration 100 / 1000: loss 2.302814
# iteration 200 / 1000: loss 2.299907
# iteration 300 / 1000: loss 2.288962
# iteration 400 / 1000: loss 2.253114
# iteration 500 / 1000: loss 2.183284
# iteration 600 / 1000: loss 2.172923
# iteration 700 / 1000: loss 2.052188
# iteration 800 / 1000: loss 2.106603
# iteration 900 / 1000: loss 2.034914
# 71
# iteration 0 / 1200: loss 2.303032
# iteration 100 / 1200: loss 2.302738
# iteration 200 / 1200: loss 2.301361
# iteration 300 / 1200: loss 2.285327
# iteration 400 / 1200: loss 2.247474
# iteration 500 / 1200: loss 2.211641
# iteration 600 / 1200: loss 2.174818
# iteration 700 / 1200: loss 2.114710
# iteration 800 / 1200: loss 2.040192
# iteration 900 / 1200: loss 2.069872
# iteration 1000 / 1200: loss 2.003125
# iteration 1100 / 1200: loss 1.871941
# 72
# iteration 0 / 1400: loss 2.303054
# iteration 100 / 1400: loss 2.302766
# iteration 200 / 1400: loss 2.301056
# iteration 300 / 1400: loss 2.287391
# iteration 400 / 1400: loss 2.248299
# iteration 500 / 1400: loss 2.208880
# iteration 600 / 1400: loss 2.186628
# iteration 700 / 1400: loss 2.111218
# iteration 800 / 1400: loss 2.068014
# iteration 900 / 1400: loss 2.026456
# iteration 1000 / 1400: loss 2.007270
# iteration 1100 / 1400: loss 1.976804
# iteration 1200 / 1400: loss 1.940188
# iteration 1300 / 1400: loss 1.931854
# 73
# iteration 0 / 1000: loss 2.303126
# iteration 100 / 1000: loss 2.302886
# iteration 200 / 1000: loss 2.301074
# iteration 300 / 1000: loss 2.292350
# iteration 400 / 1000: loss 2.253305
# iteration 500 / 1000: loss 2.204604
# iteration 600 / 1000: loss 2.154406
# iteration 700 / 1000: loss 2.026068
# iteration 800 / 1000: loss 2.072320
# iteration 900 / 1000: loss 2.058614
# 74
# iteration 0 / 1200: loss 2.303105
# iteration 100 / 1200: loss 2.302841
# iteration 200 / 1200: loss 2.300798
# iteration 300 / 1200: loss 2.291072
# iteration 400 / 1200: loss 2.254375
# iteration 500 / 1200: loss 2.185322
# iteration 600 / 1200: loss 2.131561
# iteration 700 / 1200: loss 2.082050
# iteration 800 / 1200: loss 2.076199
# iteration 900 / 1200: loss 2.046983
# iteration 1000 / 1200: loss 2.023807
# iteration 1100 / 1200: loss 2.027421
# 75
# iteration 0 / 1400: loss 2.303135
# iteration 100 / 1400: loss 2.302860
# iteration 200 / 1400: loss 2.300583
# iteration 300 / 1400: loss 2.287567
# iteration 400 / 1400: loss 2.243179
# iteration 500 / 1400: loss 2.177269
# iteration 600 / 1400: loss 2.194806
# iteration 700 / 1400: loss 2.083120
# iteration 800 / 1400: loss 2.056473
# iteration 900 / 1400: loss 1.994140
# iteration 1000 / 1400: loss 2.016197
# iteration 1100 / 1400: loss 2.050466
# iteration 1200 / 1400: loss 1.931746
# iteration 1300 / 1400: loss 1.944379
# 76
# iteration 0 / 1000: loss 2.302875
# iteration 100 / 1000: loss 2.302683
# iteration 200 / 1000: loss 2.301662
# iteration 300 / 1000: loss 2.296343
# iteration 400 / 1000: loss 2.279595
# iteration 500 / 1000: loss 2.223569
# iteration 600 / 1000: loss 2.157104
# iteration 700 / 1000: loss 2.146387
# iteration 800 / 1000: loss 2.098402
# iteration 900 / 1000: loss 2.072342
# 77
# iteration 0 / 1200: loss 2.302854
# iteration 100 / 1200: loss 2.302650
# iteration 200 / 1200: loss 2.302050
# iteration 300 / 1200: loss 2.295525
# iteration 400 / 1200: loss 2.267781
# iteration 500 / 1200: loss 2.234746
# iteration 600 / 1200: loss 2.171416
# iteration 700 / 1200: loss 2.164849
# iteration 800 / 1200: loss 2.054984
# iteration 900 / 1200: loss 2.048164
# iteration 1000 / 1200: loss 1.967502
# iteration 1100 / 1200: loss 2.066725
# 78
# iteration 0 / 1400: loss 2.302860
# iteration 100 / 1400: loss 2.302729
# iteration 200 / 1400: loss 2.302232
# iteration 300 / 1400: loss 2.298853
# iteration 400 / 1400: loss 2.288599
# iteration 500 / 1400: loss 2.232076
# iteration 600 / 1400: loss 2.212899
# iteration 700 / 1400: loss 2.136975
# iteration 800 / 1400: loss 2.113372
# iteration 900 / 1400: loss 2.076804
# iteration 1000 / 1400: loss 2.118972
# iteration 1100 / 1400: loss 2.028777
# iteration 1200 / 1400: loss 2.011485
# iteration 1300 / 1400: loss 1.939314
# 79
# iteration 0 / 1000: loss 2.302961
# iteration 100 / 1000: loss 2.302781
# iteration 200 / 1000: loss 2.301476
# iteration 300 / 1000: loss 2.293824
# iteration 400 / 1000: loss 2.290485
# iteration 500 / 1000: loss 2.198674
# iteration 600 / 1000: loss 2.175361
# iteration 700 / 1000: loss 2.078318
# iteration 800 / 1000: loss 2.052812
# iteration 900 / 1000: loss 2.067076
# 80
# iteration 0 / 1200: loss 2.302946
# iteration 100 / 1200: loss 2.302714
# iteration 200 / 1200: loss 2.301794
# iteration 300 / 1200: loss 2.296150
# iteration 400 / 1200: loss 2.265329
# iteration 500 / 1200: loss 2.210099
# iteration 600 / 1200: loss 2.127870
# iteration 700 / 1200: loss 2.122319
# iteration 800 / 1200: loss 2.103408
# iteration 900 / 1200: loss 2.064254
# iteration 1000 / 1200: loss 2.022274
# iteration 1100 / 1200: loss 1.984773
# 81
# iteration 0 / 1400: loss 2.302962
# iteration 100 / 1400: loss 2.302723
# iteration 200 / 1400: loss 2.301672
# iteration 300 / 1400: loss 2.299036
# iteration 400 / 1400: loss 2.273116
# iteration 500 / 1400: loss 2.205522
# iteration 600 / 1400: loss 2.187554
# iteration 700 / 1400: loss 2.073104
# iteration 800 / 1400: loss 2.097790
# iteration 900 / 1400: loss 2.057898
# iteration 1000 / 1400: loss 2.021374
# iteration 1100 / 1400: loss 2.047290
# iteration 1200 / 1400: loss 2.008470
# iteration 1300 / 1400: loss 1.998726
# 82
# iteration 0 / 1000: loss 2.303025
# iteration 100 / 1000: loss 2.302642
# iteration 200 / 1000: loss 2.300763
# iteration 300 / 1000: loss 2.286785
# iteration 400 / 1000: loss 2.246746
# iteration 500 / 1000: loss 2.220468
# iteration 600 / 1000: loss 2.217903
# iteration 700 / 1000: loss 2.086494
# iteration 800 / 1000: loss 2.067933
# iteration 900 / 1000: loss 2.034580
# 83
# iteration 0 / 1200: loss 2.303047
# iteration 100 / 1200: loss 2.302803
# iteration 200 / 1200: loss 2.301663
# iteration 300 / 1200: loss 2.293344
# iteration 400 / 1200: loss 2.262821
# iteration 500 / 1200: loss 2.204559
# iteration 600 / 1200: loss 2.153206
# iteration 700 / 1200: loss 2.109049
# iteration 800 / 1200: loss 2.078931
# iteration 900 / 1200: loss 2.091514
# iteration 1000 / 1200: loss 2.072604
# iteration 1100 / 1200: loss 1.987462
# 84
# iteration 0 / 1400: loss 2.303043
# iteration 100 / 1400: loss 2.302838
# iteration 200 / 1400: loss 2.301679
# iteration 300 / 1400: loss 2.294154
# iteration 400 / 1400: loss 2.258859
# iteration 500 / 1400: loss 2.204455
# iteration 600 / 1400: loss 2.161789
# iteration 700 / 1400: loss 2.107945
# iteration 800 / 1400: loss 2.089530
# iteration 900 / 1400: loss 2.047485
# iteration 1000 / 1400: loss 2.027036
# iteration 1100 / 1400: loss 2.023786
# iteration 1200 / 1400: loss 2.002436
# iteration 1300 / 1400: loss 1.984113
# 85
# iteration 0 / 1000: loss 2.303133
# iteration 100 / 1000: loss 2.302811
# iteration 200 / 1000: loss 2.301635
# iteration 300 / 1000: loss 2.295262
# iteration 400 / 1000: loss 2.265560
# iteration 500 / 1000: loss 2.243206
# iteration 600 / 1000: loss 2.133983
# iteration 700 / 1000: loss 2.086993
# iteration 800 / 1000: loss 2.037783
# iteration 900 / 1000: loss 2.055104
# 86
# iteration 0 / 1200: loss 2.303111
# iteration 100 / 1200: loss 2.302752
# iteration 200 / 1200: loss 2.301597
# iteration 300 / 1200: loss 2.296156
# iteration 400 / 1200: loss 2.266686
# iteration 500 / 1200: loss 2.194608
# iteration 600 / 1200: loss 2.159417
# iteration 700 / 1200: loss 2.052463
# iteration 800 / 1200: loss 2.075910
# iteration 900 / 1200: loss 2.087830
# iteration 1000 / 1200: loss 2.016042
# iteration 1100 / 1200: loss 1.974557
# 87
# iteration 0 / 1400: loss 2.303111
# iteration 100 / 1400: loss 2.302863
# iteration 200 / 1400: loss 2.301465
# iteration 300 / 1400: loss 2.295377
# iteration 400 / 1400: loss 2.243861
# iteration 500 / 1400: loss 2.178430
# iteration 600 / 1400: loss 2.140240
# iteration 700 / 1400: loss 2.128150
# iteration 800 / 1400: loss 2.082803
# iteration 900 / 1400: loss 2.010831
# iteration 1000 / 1400: loss 1.982569
# iteration 1100 / 1400: loss 1.952279
# iteration 1200 / 1400: loss 1.950762
# iteration 1300 / 1400: loss 1.886687
# 88
# iteration 0 / 1000: loss 2.303216
# iteration 100 / 1000: loss 2.302905
# iteration 200 / 1000: loss 2.301412
# iteration 300 / 1000: loss 2.292326
# iteration 400 / 1000: loss 2.260081
# iteration 500 / 1000: loss 2.217785
# iteration 600 / 1000: loss 2.111122
# iteration 700 / 1000: loss 2.089882
# iteration 800 / 1000: loss 2.020098
# iteration 900 / 1000: loss 2.112083
# 89
# iteration 0 / 1200: loss 2.303204
# iteration 100 / 1200: loss 2.302921
# iteration 200 / 1200: loss 2.300959
# iteration 300 / 1200: loss 2.290451
# iteration 400 / 1200: loss 2.267731
# iteration 500 / 1200: loss 2.187136
# iteration 600 / 1200: loss 2.125345
# iteration 700 / 1200: loss 2.051574
# iteration 800 / 1200: loss 2.090206
# iteration 900 / 1200: loss 1.970711
# iteration 1000 / 1200: loss 2.034489
# iteration 1100 / 1200: loss 1.923999
# 90
# iteration 0 / 1400: loss 2.303229
# iteration 100 / 1400: loss 2.302779
# iteration 200 / 1400: loss 2.300877
# iteration 300 / 1400: loss 2.292508
# iteration 400 / 1400: loss 2.234184
# iteration 500 / 1400: loss 2.181043
# iteration 600 / 1400: loss 2.173243
# iteration 700 / 1400: loss 2.084668
# iteration 800 / 1400: loss 2.055544
# iteration 900 / 1400: loss 2.024768
# iteration 1000 / 1400: loss 2.054606
# iteration 1100 / 1400: loss 2.096168
# iteration 1200 / 1400: loss 1.976793
# iteration 1300 / 1400: loss 1.980339
# 91
# iteration 0 / 1000: loss 2.302771
# iteration 100 / 1000: loss 2.302674
# iteration 200 / 1000: loss 2.302466
# iteration 300 / 1000: loss 2.301554
# iteration 400 / 1000: loss 2.299147
# iteration 500 / 1000: loss 2.290177
# iteration 600 / 1000: loss 2.257681
# iteration 700 / 1000: loss 2.210535
# iteration 800 / 1000: loss 2.154898
# iteration 900 / 1000: loss 2.214201
# 92
# iteration 0 / 1200: loss 2.302790
# iteration 100 / 1200: loss 2.302692
# iteration 200 / 1200: loss 2.302467
# iteration 300 / 1200: loss 2.301469
# iteration 400 / 1200: loss 2.299193
# iteration 500 / 1200: loss 2.287311
# iteration 600 / 1200: loss 2.265977
# iteration 700 / 1200: loss 2.222753
# iteration 800 / 1200: loss 2.159080
# iteration 900 / 1200: loss 2.159139
# iteration 1000 / 1200: loss 2.140448
# iteration 1100 / 1200: loss 2.123409
# 93
# iteration 0 / 1400: loss 2.302768
# iteration 100 / 1400: loss 2.302669
# iteration 200 / 1400: loss 2.302316
# iteration 300 / 1400: loss 2.300854
# iteration 400 / 1400: loss 2.296800
# iteration 500 / 1400: loss 2.282778
# iteration 600 / 1400: loss 2.263979
# iteration 700 / 1400: loss 2.258279
# iteration 800 / 1400: loss 2.216121
# iteration 900 / 1400: loss 2.182389
# iteration 1000 / 1400: loss 2.148259
# iteration 1100 / 1400: loss 2.068636
# iteration 1200 / 1400: loss 2.058469
# iteration 1300 / 1400: loss 2.105797
# 94
# iteration 0 / 1000: loss 2.302839
# iteration 100 / 1000: loss 2.302745
# iteration 200 / 1000: loss 2.302255
# iteration 300 / 1000: loss 2.301504
# iteration 400 / 1000: loss 2.295747
# iteration 500 / 1000: loss 2.277449
# iteration 600 / 1000: loss 2.243224
# iteration 700 / 1000: loss 2.221761
# iteration 800 / 1000: loss 2.186870
# iteration 900 / 1000: loss 2.146334
# 95
# iteration 0 / 1200: loss 2.302871
# iteration 100 / 1200: loss 2.302718
# iteration 200 / 1200: loss 2.302397
# iteration 300 / 1200: loss 2.301573
# iteration 400 / 1200: loss 2.297476
# iteration 500 / 1200: loss 2.284060
# iteration 600 / 1200: loss 2.264487
# iteration 700 / 1200: loss 2.213953
# iteration 800 / 1200: loss 2.189136
# iteration 900 / 1200: loss 2.179677
# iteration 1000 / 1200: loss 2.116735
# iteration 1100 / 1200: loss 2.115055
# 96
# iteration 0 / 1400: loss 2.302817
# iteration 100 / 1400: loss 2.302691
# iteration 200 / 1400: loss 2.302446
# iteration 300 / 1400: loss 2.300805
# iteration 400 / 1400: loss 2.295659
# iteration 500 / 1400: loss 2.285224
# iteration 600 / 1400: loss 2.267994
# iteration 700 / 1400: loss 2.210057
# iteration 800 / 1400: loss 2.199152
# iteration 900 / 1400: loss 2.149268
# iteration 1000 / 1400: loss 2.161261
# iteration 1100 / 1400: loss 2.152755
# iteration 1200 / 1400: loss 2.011246
# iteration 1300 / 1400: loss 2.054531
# 97
# iteration 0 / 1000: loss 2.302882
# iteration 100 / 1000: loss 2.302767
# iteration 200 / 1000: loss 2.302338
# iteration 300 / 1000: loss 2.301640
# iteration 400 / 1000: loss 2.297387
# iteration 500 / 1000: loss 2.287811
# iteration 600 / 1000: loss 2.245436
# iteration 700 / 1000: loss 2.232673
# iteration 800 / 1000: loss 2.180364
# iteration 900 / 1000: loss 2.129447
# 98
# iteration 0 / 1200: loss 2.302912
# iteration 100 / 1200: loss 2.302752
# iteration 200 / 1200: loss 2.302433
# iteration 300 / 1200: loss 2.301685
# iteration 400 / 1200: loss 2.297968
# iteration 500 / 1200: loss 2.289036
# iteration 600 / 1200: loss 2.259918
# iteration 700 / 1200: loss 2.242270
# iteration 800 / 1200: loss 2.187922
# iteration 900 / 1200: loss 2.173181
# iteration 1000 / 1200: loss 2.102013
# iteration 1100 / 1200: loss 2.057272
# 99
# iteration 0 / 1400: loss 2.302900
# iteration 100 / 1400: loss 2.302736
# iteration 200 / 1400: loss 2.302332
# iteration 300 / 1400: loss 2.300808
# iteration 400 / 1400: loss 2.297118
# iteration 500 / 1400: loss 2.284232
# iteration 600 / 1400: loss 2.259857
# iteration 700 / 1400: loss 2.219856
# iteration 800 / 1400: loss 2.130997
# iteration 900 / 1400: loss 2.180867
# iteration 1000 / 1400: loss 2.138321
# iteration 1100 / 1400: loss 2.046120
# iteration 1200 / 1400: loss 2.086639
# iteration 1300 / 1400: loss 2.076999
# 100
# iteration 0 / 1000: loss 2.302961
# iteration 100 / 1000: loss 2.302796
# iteration 200 / 1000: loss 2.302253
# iteration 300 / 1000: loss 2.301497
# iteration 400 / 1000: loss 2.295849
# iteration 500 / 1000: loss 2.278860
# iteration 600 / 1000: loss 2.240290
# iteration 700 / 1000: loss 2.211778
# iteration 800 / 1000: loss 2.231900
# iteration 900 / 1000: loss 2.123270
# 101
# iteration 0 / 1200: loss 2.302941
# iteration 100 / 1200: loss 2.302779
# iteration 200 / 1200: loss 2.302040
# iteration 300 / 1200: loss 2.300792
# iteration 400 / 1200: loss 2.296577
# iteration 500 / 1200: loss 2.285705
# iteration 600 / 1200: loss 2.232514
# iteration 700 / 1200: loss 2.229419
# iteration 800 / 1200: loss 2.147776
# iteration 900 / 1200: loss 2.096432
# iteration 1000 / 1200: loss 2.115392
# iteration 1100 / 1200: loss 2.074481
# 102
# iteration 0 / 1400: loss 2.302959
# iteration 100 / 1400: loss 2.302781
# iteration 200 / 1400: loss 2.302419
# iteration 300 / 1400: loss 2.301266
# iteration 400 / 1400: loss 2.295618
# iteration 500 / 1400: loss 2.285657
# iteration 600 / 1400: loss 2.262817
# iteration 700 / 1400: loss 2.201737
# iteration 800 / 1400: loss 2.159435
# iteration 900 / 1400: loss 2.152174
# iteration 1000 / 1400: loss 2.091168
# iteration 1100 / 1400: loss 2.134978
# iteration 1200 / 1400: loss 2.096175
# iteration 1300 / 1400: loss 2.018839
# 103
# iteration 0 / 1000: loss 2.303063
# iteration 100 / 1000: loss 2.302876
# iteration 200 / 1000: loss 2.302318
# iteration 300 / 1000: loss 2.301497
# iteration 400 / 1000: loss 2.296649
# iteration 500 / 1000: loss 2.290613
# iteration 600 / 1000: loss 2.240188
# iteration 700 / 1000: loss 2.198457
# iteration 800 / 1000: loss 2.179800
# iteration 900 / 1000: loss 2.150689
# 104
# iteration 0 / 1200: loss 2.303005
# iteration 100 / 1200: loss 2.302742
# iteration 200 / 1200: loss 2.302056
# iteration 300 / 1200: loss 2.299480
# iteration 400 / 1200: loss 2.292216
# iteration 500 / 1200: loss 2.270093
# iteration 600 / 1200: loss 2.236760
# iteration 700 / 1200: loss 2.181814
# iteration 800 / 1200: loss 2.153110
# iteration 900 / 1200: loss 2.140471
# iteration 1000 / 1200: loss 2.062192
# iteration 1100 / 1200: loss 2.055943
# 105
# iteration 0 / 1400: loss 2.303016
# iteration 100 / 1400: loss 2.302854
# iteration 200 / 1400: loss 2.302218
# iteration 300 / 1400: loss 2.300716
# iteration 400 / 1400: loss 2.294843
# iteration 500 / 1400: loss 2.270910
# iteration 600 / 1400: loss 2.216923
# iteration 700 / 1400: loss 2.206511
# iteration 800 / 1400: loss 2.177626
# iteration 900 / 1400: loss 2.159146
# iteration 1000 / 1400: loss 2.077181
# iteration 1100 / 1400: loss 2.073502
# iteration 1200 / 1400: loss 1.990144
# iteration 1300 / 1400: loss 2.068211
# 106
# iteration 0 / 1000: loss 2.302819
# iteration 100 / 1000: loss 2.302723
# iteration 200 / 1000: loss 2.302481
# iteration 300 / 1000: loss 2.301527
# iteration 400 / 1000: loss 2.297790
# iteration 500 / 1000: loss 2.277867
# iteration 600 / 1000: loss 2.261416
# iteration 700 / 1000: loss 2.226210
# iteration 800 / 1000: loss 2.223590
# iteration 900 / 1000: loss 2.200907
# 107
# iteration 0 / 1200: loss 2.302814
# iteration 100 / 1200: loss 2.302731
# iteration 200 / 1200: loss 2.302502
# iteration 300 / 1200: loss 2.301707
# iteration 400 / 1200: loss 2.298065
# iteration 500 / 1200: loss 2.290081
# iteration 600 / 1200: loss 2.263114
# iteration 700 / 1200: loss 2.222458
# iteration 800 / 1200: loss 2.210439
# iteration 900 / 1200: loss 2.193469
# iteration 1000 / 1200: loss 2.148453
# iteration 1100 / 1200: loss 2.134814
# 108
# iteration 0 / 1400: loss 2.302797
# iteration 100 / 1400: loss 2.302715
# iteration 200 / 1400: loss 2.302335
# iteration 300 / 1400: loss 2.300894
# iteration 400 / 1400: loss 2.298568
# iteration 500 / 1400: loss 2.284214
# iteration 600 / 1400: loss 2.247630
# iteration 700 / 1400: loss 2.214651
# iteration 800 / 1400: loss 2.183014
# iteration 900 / 1400: loss 2.160551
# iteration 1000 / 1400: loss 2.110034
# iteration 1100 / 1400: loss 2.119436
# iteration 1200 / 1400: loss 2.042070
# iteration 1300 / 1400: loss 2.072292
# 109
# iteration 0 / 1000: loss 2.302881
# iteration 100 / 1000: loss 2.302755
# iteration 200 / 1000: loss 2.302390
# iteration 300 / 1000: loss 2.300484
# iteration 400 / 1000: loss 2.298879
# iteration 500 / 1000: loss 2.280987
# iteration 600 / 1000: loss 2.244765
# iteration 700 / 1000: loss 2.197220
# iteration 800 / 1000: loss 2.202817
# iteration 900 / 1000: loss 2.179153
# 110
# iteration 0 / 1200: loss 2.302903
# iteration 100 / 1200: loss 2.302798
# iteration 200 / 1200: loss 2.302574
# iteration 300 / 1200: loss 2.301933
# iteration 400 / 1200: loss 2.299880
# iteration 500 / 1200: loss 2.290835
# iteration 600 / 1200: loss 2.276771
# iteration 700 / 1200: loss 2.231391
# iteration 800 / 1200: loss 2.166587
# iteration 900 / 1200: loss 2.145933
# iteration 1000 / 1200: loss 2.143203
# iteration 1100 / 1200: loss 2.100793
# 111
# iteration 0 / 1400: loss 2.302897
# iteration 100 / 1400: loss 2.302778
# iteration 200 / 1400: loss 2.302502
# iteration 300 / 1400: loss 2.301549
# iteration 400 / 1400: loss 2.298038
# iteration 500 / 1400: loss 2.285883
# ...
# iteration 600 / 1000: loss 2.302752
# iteration 700 / 1000: loss 2.302722
# iteration 800 / 1000: loss 2.302633
# iteration 900 / 1000: loss 2.302570
# 191
# iteration 0 / 1200: loss 2.302963
# iteration 100 / 1200: loss 2.302917
# iteration 200 / 1200: loss 2.302905
# iteration 300 / 1200: loss 2.302871
# iteration 400 / 1200: loss 2.302853
# iteration 500 / 1200: loss 2.302777
# iteration 600 / 1200: loss 2.302777
# iteration 700 / 1200: loss 2.302689
# iteration 800 / 1200: loss 2.302629
# iteration 900 / 1200: loss 2.302572
# iteration 1000 / 1200: loss 2.302569
# iteration 1100 / 1200: loss 2.302443
# 192
# iteration 0 / 1400: loss 2.302968
# iteration 100 / 1400: loss 2.302924
# iteration 200 / 1400: loss 2.302904
# iteration 300 / 1400: loss 2.302853
# iteration 400 / 1400: loss 2.302840
# iteration 500 / 1400: loss 2.302789
# iteration 600 / 1400: loss 2.302745
# iteration 700 / 1400: loss 2.302685
# iteration 800 / 1400: loss 2.302687
# iteration 900 / 1400: loss 2.302516
# iteration 1000 / 1400: loss 2.302497
# iteration 1100 / 1400: loss 2.302446
# iteration 1200 / 1400: loss 2.302174
# iteration 1300 / 1400: loss 2.302121
# 193
# iteration 0 / 1000: loss 2.303030
# iteration 100 / 1000: loss 2.302983
# iteration 200 / 1000: loss 2.302910
# iteration 300 / 1000: loss 2.302886
# iteration 400 / 1000: loss 2.302833
# iteration 500 / 1000: loss 2.302823
# iteration 600 / 1000: loss 2.302660
# iteration 700 / 1000: loss 2.302731
# iteration 800 / 1000: loss 2.302475
# iteration 900 / 1000: loss 2.302432
# 194
# iteration 0 / 1200: loss 2.303030
# iteration 100 / 1200: loss 2.303016
# iteration 200 / 1200: loss 2.302977
# iteration 300 / 1200: loss 2.302937
# iteration 400 / 1200: loss 2.302879
# iteration 500 / 1200: loss 2.302874
# iteration 600 / 1200: loss 2.302822
# iteration 700 / 1200: loss 2.302745
# iteration 800 / 1200: loss 2.302645
# iteration 900 / 1200: loss 2.302564
# iteration 1000 / 1200: loss 2.302586
# iteration 1100 / 1200: loss 2.302507
# 195
# iteration 0 / 1400: loss 2.303020
# iteration 100 / 1400: loss 2.302966
# iteration 200 / 1400: loss 2.302955
# iteration 300 / 1400: loss 2.302864
# iteration 400 / 1400: loss 2.302834
# iteration 500 / 1400: loss 2.302803
# iteration 600 / 1400: loss 2.302803
# iteration 700 / 1400: loss 2.302697
# iteration 800 / 1400: loss 2.302711
# iteration 900 / 1400: loss 2.302564
# iteration 1000 / 1400: loss 2.302407
# iteration 1100 / 1400: loss 2.302269
# iteration 1200 / 1400: loss 2.302173
# iteration 1300 / 1400: loss 2.301835
# 196
# iteration 0 / 1000: loss 2.302816
# iteration 100 / 1000: loss 2.302802
# iteration 200 / 1000: loss 2.302800
# iteration 300 / 1000: loss 2.302788
# iteration 400 / 1000: loss 2.302763
# iteration 500 / 1000: loss 2.302750
# iteration 600 / 1000: loss 2.302772
# iteration 700 / 1000: loss 2.302707
# iteration 800 / 1000: loss 2.302649
# iteration 900 / 1000: loss 2.302601
# 197
# iteration 0 / 1200: loss 2.302847
# iteration 100 / 1200: loss 2.302801
# iteration 200 / 1200: loss 2.302815
# iteration 300 / 1200: loss 2.302797
# iteration 400 / 1200: loss 2.302810
# iteration 500 / 1200: loss 2.302784
# iteration 600 / 1200: loss 2.302766
# iteration 700 / 1200: loss 2.302761
# iteration 800 / 1200: loss 2.302752
# iteration 900 / 1200: loss 2.302693
# iteration 1000 / 1200: loss 2.302713
# iteration 1100 / 1200: loss 2.302680
# 198
# iteration 0 / 1400: loss 2.302823
# iteration 100 / 1400: loss 2.302802
# iteration 200 / 1400: loss 2.302782
# iteration 300 / 1400: loss 2.302773
# iteration 400 / 1400: loss 2.302766
# iteration 500 / 1400: loss 2.302719
# iteration 600 / 1400: loss 2.302713
# iteration 700 / 1400: loss 2.302697
# iteration 800 / 1400: loss 2.302592
# iteration 900 / 1400: loss 2.302583
# iteration 1000 / 1400: loss 2.302481
# iteration 1100 / 1400: loss 2.302396
# iteration 1200 / 1400: loss 2.302400
# iteration 1300 / 1400: loss 2.302418
# 199
# iteration 0 / 1000: loss 2.302889
# iteration 100 / 1000: loss 2.302877
# iteration 200 / 1000: loss 2.302873
# iteration 300 / 1000: loss 2.302833
# iteration 400 / 1000: loss 2.302819
# iteration 500 / 1000: loss 2.302805
# iteration 600 / 1000: loss 2.302776
# iteration 700 / 1000: loss 2.302751
# iteration 800 / 1000: loss 2.302694
# iteration 900 / 1000: loss 2.302661
# 200
# iteration 0 / 1200: loss 2.302897
# iteration 100 / 1200: loss 2.302898
# iteration 200 / 1200: loss 2.302865
# iteration 300 / 1200: loss 2.302847
# iteration 400 / 1200: loss 2.302833
# iteration 500 / 1200: loss 2.302720
# iteration 600 / 1200: loss 2.302691
# iteration 700 / 1200: loss 2.302637
# iteration 800 / 1200: loss 2.302577
# iteration 900 / 1200: loss 2.302646
# iteration 1000 / 1200: loss 2.302565
# iteration 1100 / 1200: loss 2.302456
# 201
# iteration 0 / 1400: loss 2.302887
# iteration 100 / 1400: loss 2.302870
# iteration 200 / 1400: loss 2.302852
# iteration 300 / 1400: loss 2.302828
# iteration 400 / 1400: loss 2.302830
# iteration 500 / 1400: loss 2.302770
# iteration 600 / 1400: loss 2.302742
# iteration 700 / 1400: loss 2.302712
# iteration 800 / 1400: loss 2.302658
# iteration 900 / 1400: loss 2.302712
# iteration 1000 / 1400: loss 2.302550
# iteration 1100 / 1400: loss 2.302483
# iteration 1200 / 1400: loss 2.302497
# iteration 1300 / 1400: loss 2.302195
# 202
# iteration 0 / 1000: loss 2.302982
# iteration 100 / 1000: loss 2.302982
# iteration 200 / 1000: loss 2.302933
# iteration 300 / 1000: loss 2.302948
# iteration 400 / 1000: loss 2.302908
# iteration 500 / 1000: loss 2.302899
# iteration 600 / 1000: loss 2.302862
# iteration 700 / 1000: loss 2.302811
# iteration 800 / 1000: loss 2.302790
# iteration 900 / 1000: loss 2.302772
# 203
# iteration 0 / 1200: loss 2.302921
# iteration 100 / 1200: loss 2.302948
# iteration 200 / 1200: loss 2.302912
# iteration 300 / 1200: loss 2.302878
# iteration 400 / 1200: loss 2.302842
# iteration 500 / 1200: loss 2.302825
# iteration 600 / 1200: loss 2.302810
# iteration 700 / 1200: loss 2.302719
# iteration 800 / 1200: loss 2.302684
# iteration 900 / 1200: loss 2.302606
# iteration 1000 / 1200: loss 2.302527
# iteration 1100 / 1200: loss 2.302454
# 204
# iteration 0 / 1400: loss 2.302982
# iteration 100 / 1400: loss 2.302934
# iteration 200 / 1400: loss 2.302887
# iteration 300 / 1400: loss 2.302920
# iteration 400 / 1400: loss 2.302836
# iteration 500 / 1400: loss 2.302845
# iteration 600 / 1400: loss 2.302768
# iteration 700 / 1400: loss 2.302759
# iteration 800 / 1400: loss 2.302672
# iteration 900 / 1400: loss 2.302567
# iteration 1000 / 1400: loss 2.302576
# iteration 1100 / 1400: loss 2.302385
# iteration 1200 / 1400: loss 2.302197
# iteration 1300 / 1400: loss 2.302100
# 205
# iteration 0 / 1000: loss 2.303031
# iteration 100 / 1000: loss 2.303041
# iteration 200 / 1000: loss 2.302989
# iteration 300 / 1000: loss 2.302963
# iteration 400 / 1000: loss 2.302907
# iteration 500 / 1000: loss 2.302878
# iteration 600 / 1000: loss 2.302800
# iteration 700 / 1000: loss 2.302747
# iteration 800 / 1000: loss 2.302753
# iteration 900 / 1000: loss 2.302643
# 206
# iteration 0 / 1200: loss 2.303030
# iteration 100 / 1200: loss 2.303004
# iteration 200 / 1200: loss 2.302977
# iteration 300 / 1200: loss 2.302958
# iteration 400 / 1200: loss 2.302923
# iteration 500 / 1200: loss 2.302867
# iteration 600 / 1200: loss 2.302821
# iteration 700 / 1200: loss 2.302764
# iteration 800 / 1200: loss 2.302632
# iteration 900 / 1200: loss 2.302567
# iteration 1000 / 1200: loss 2.302507
# iteration 1100 / 1200: loss 2.302520
# 207
# iteration 0 / 1400: loss 2.303053
# iteration 100 / 1400: loss 2.303016
# iteration 200 / 1400: loss 2.302999
# iteration 300 / 1400: loss 2.303000
# iteration 400 / 1400: loss 2.302946
# iteration 500 / 1400: loss 2.302944
# iteration 600 / 1400: loss 2.302906
# iteration 700 / 1400: loss 2.302843
# iteration 800 / 1400: loss 2.302843
# iteration 900 / 1400: loss 2.302764
# iteration 1000 / 1400: loss 2.302663
# iteration 1100 / 1400: loss 2.302639
# iteration 1200 / 1400: loss 2.302511
# iteration 1300 / 1400: loss 2.302454
# 208
# iteration 0 / 1000: loss 2.303131
# iteration 100 / 1000: loss 2.303102
# iteration 200 / 1000: loss 2.303051
# iteration 300 / 1000: loss 2.303008
# iteration 400 / 1000: loss 2.302973
# iteration 500 / 1000: loss 2.302937
# iteration 600 / 1000: loss 2.302855
# iteration 700 / 1000: loss 2.302843
# iteration 800 / 1000: loss 2.302764
# iteration 900 / 1000: loss 2.302679
# 209
# iteration 0 / 1200: loss 2.303096
# iteration 100 / 1200: loss 2.303037
# iteration 200 / 1200: loss 2.303031
# iteration 300 / 1200: loss 2.302991
# iteration 400 / 1200: loss 2.302965
# iteration 500 / 1200: loss 2.302945
# iteration 600 / 1200: loss 2.302911
# iteration 700 / 1200: loss 2.302722
# iteration 800 / 1200: loss 2.302810
# iteration 900 / 1200: loss 2.302817
# iteration 1000 / 1200: loss 2.302611
# iteration 1100 / 1200: loss 2.302481
# 210
# iteration 0 / 1400: loss 2.303129
# iteration 100 / 1400: loss 2.303085
# iteration 200 / 1400: loss 2.303063
# iteration 300 / 1400: loss 2.303016
# iteration 400 / 1400: loss 2.302987
# iteration 500 / 1400: loss 2.302946
# iteration 600 / 1400: loss 2.302920
# iteration 700 / 1400: loss 2.302866
# iteration 800 / 1400: loss 2.302801
# iteration 900 / 1400: loss 2.302635
# iteration 1000 / 1400: loss 2.302699
# iteration 1100 / 1400: loss 2.302566
# iteration 1200 / 1400: loss 2.302538
# iteration 1300 / 1400: loss 2.302140
# 211
# iteration 0 / 1000: loss 2.302860
# iteration 100 / 1000: loss 2.302841
# iteration 200 / 1000: loss 2.302823
# iteration 300 / 1000: loss 2.302800
# iteration 400 / 1000: loss 2.302768
# iteration 500 / 1000: loss 2.302745
# iteration 600 / 1000: loss 2.302746
# iteration 700 / 1000: loss 2.302685
# iteration 800 / 1000: loss 2.302663
# iteration 900 / 1000: loss 2.302618
# 212
# iteration 0 / 1200: loss 2.302875
# iteration 100 / 1200: loss 2.302853
# iteration 200 / 1200: loss 2.302831
# iteration 300 / 1200: loss 2.302800
# iteration 400 / 1200: loss 2.302766
# iteration 500 / 1200: loss 2.302787
# iteration 600 / 1200: loss 2.302743
# iteration 700 / 1200: loss 2.302703
# iteration 800 / 1200: loss 2.302682
# iteration 900 / 1200: loss 2.302659
# iteration 1000 / 1200: loss 2.302582
# iteration 1100 / 1200: loss 2.302581
# 213
# iteration 0 / 1400: loss 2.302868
# iteration 100 / 1400: loss 2.302828
# iteration 200 / 1400: loss 2.302857
# iteration 300 / 1400: loss 2.302798
# iteration 400 / 1400: loss 2.302774
# iteration 500 / 1400: loss 2.302723
# iteration 600 / 1400: loss 2.302682
# iteration 700 / 1400: loss 2.302701
# iteration 800 / 1400: loss 2.302656
# iteration 900 / 1400: loss 2.302572
# iteration 1000 / 1400: loss 2.302532
# iteration 1100 / 1400: loss 2.302459
# iteration 1200 / 1400: loss 2.302365
# iteration 1300 / 1400: loss 2.302348
# 214
# iteration 0 / 1000: loss 2.302934
# iteration 100 / 1000: loss 2.302922
# iteration 200 / 1000: loss 2.302897
# iteration 300 / 1000: loss 2.302876
# iteration 400 / 1000: loss 2.302877
# iteration 500 / 1000: loss 2.302814
# iteration 600 / 1000: loss 2.302827
# iteration 700 / 1000: loss 2.302767
# iteration 800 / 1000: loss 2.302735
# iteration 900 / 1000: loss 2.302720
# 215
# iteration 0 / 1200: loss 2.302941
# iteration 100 / 1200: loss 2.302926
# iteration 200 / 1200: loss 2.302893
# iteration 300 / 1200: loss 2.302888
# iteration 400 / 1200: loss 2.302859
# iteration 500 / 1200: loss 2.302815
# iteration 600 / 1200: loss 2.302776
# iteration 700 / 1200: loss 2.302737
# iteration 800 / 1200: loss 2.302712
# iteration 900 / 1200: loss 2.302610
# iteration 1000 / 1200: loss 2.302620
# iteration 1100 / 1200: loss 2.302422
# 216
# iteration 0 / 1400: loss 2.302922
# iteration 100 / 1400: loss 2.302946
# iteration 200 / 1400: loss 2.302907
# iteration 300 / 1400: loss 2.302904
# iteration 400 / 1400: loss 2.302854
# iteration 500 / 1400: loss 2.302782
# iteration 600 / 1400: loss 2.302762
# iteration 700 / 1400: loss 2.302685
# iteration 800 / 1400: loss 2.302670
# iteration 900 / 1400: loss 2.302468
# iteration 1000 / 1400: loss 2.302522
# iteration 1100 / 1400: loss 2.302372
# iteration 1200 / 1400: loss 2.302309
# iteration 1300 / 1400: loss 2.302214
# 217
# iteration 0 / 1000: loss 2.303002
# iteration 100 / 1000: loss 2.302967
# iteration 200 / 1000: loss 2.302948
# iteration 300 / 1000: loss 2.302958
# iteration 400 / 1000: loss 2.302876
# iteration 500 / 1000: loss 2.302847
# iteration 600 / 1000: loss 2.302806
# iteration 700 / 1000: loss 2.302658
# iteration 800 / 1000: loss 2.302803
# iteration 900 / 1000: loss 2.302567
# 218
# iteration 0 / 1200: loss 2.303039
# iteration 100 / 1200: loss 2.303040
# iteration 200 / 1200: loss 2.303016
# iteration 300 / 1200: loss 2.302994
# iteration 400 / 1200: loss 2.302962
# iteration 500 / 1200: loss 2.302937
# iteration 600 / 1200: loss 2.302913
# iteration 700 / 1200: loss 2.302894
# iteration 800 / 1200: loss 2.302792
# iteration 900 / 1200: loss 2.302812
# iteration 1000 / 1200: loss 2.302703
# iteration 1100 / 1200: loss 2.302677
# 219
# iteration 0 / 1400: loss 2.303044
# iteration 100 / 1400: loss 2.303038
# iteration 200 / 1400: loss 2.302978
# iteration 300 / 1400: loss 2.302950
# iteration 400 / 1400: loss 2.302957
# iteration 500 / 1400: loss 2.302906
# iteration 600 / 1400: loss 2.302892
# iteration 700 / 1400: loss 2.302905
# iteration 800 / 1400: loss 2.302760
# iteration 900 / 1400: loss 2.302699
# iteration 1000 / 1400: loss 2.302694
# iteration 1100 / 1400: loss 2.302488
# iteration 1200 / 1400: loss 2.302504
# iteration 1300 / 1400: loss 2.302271
# 220
# iteration 0 / 1000: loss 2.303134
# iteration 100 / 1000: loss 2.303095
# iteration 200 / 1000: loss 2.303075
# iteration 300 / 1000: loss 2.303047
# iteration 400 / 1000: loss 2.302982
# iteration 500 / 1000: loss 2.302953
# iteration 600 / 1000: loss 2.302887
# iteration 700 / 1000: loss 2.302839
# iteration 800 / 1000: loss 2.302770
# iteration 900 / 1000: loss 2.302712
# 221
# iteration 0 / 1200: loss 2.303117
# iteration 100 / 1200: loss 2.303119
# iteration 200 / 1200: loss 2.303095
# iteration 300 / 1200: loss 2.303019
# iteration 400 / 1200: loss 2.303035
# iteration 500 / 1200: loss 2.302974
# iteration 600 / 1200: loss 2.302919
# iteration 700 / 1200: loss 2.302807
# iteration 800 / 1200: loss 2.302893
# iteration 900 / 1200: loss 2.302640
# iteration 1000 / 1200: loss 2.302604
# iteration 1100 / 1200: loss 2.302739
# 222
# iteration 0 / 1400: loss 2.303112
# iteration 100 / 1400: loss 2.303097
# iteration 200 / 1400: loss 2.303060
# iteration 300 / 1400: loss 2.302966
# iteration 400 / 1400: loss 2.303018
# iteration 500 / 1400: loss 2.302920
# iteration 600 / 1400: loss 2.302892
# iteration 700 / 1400: loss 2.302876
# iteration 800 / 1400: loss 2.302759
# iteration 900 / 1400: loss 2.302681
# iteration 1000 / 1400: loss 2.302496
# iteration 1100 / 1400: loss 2.302260
# iteration 1200 / 1400: loss 2.302192
# iteration 1300 / 1400: loss 2.301924
# 223
# iteration 0 / 1000: loss 2.303193
# iteration 100 / 1000: loss 2.303185
# iteration 200 / 1000: loss 2.303142
# iteration 300 / 1000: loss 2.303083
# iteration 400 / 1000: loss 2.303070
# iteration 500 / 1000: loss 2.303032
# iteration 600 / 1000: loss 2.302973
# iteration 700 / 1000: loss 2.302927
# iteration 800 / 1000: loss 2.302863
# iteration 900 / 1000: loss 2.302861
# 224
# iteration 0 / 1200: loss 2.303263
# iteration 100 / 1200: loss 2.303241
# iteration 200 / 1200: loss 2.303190
# iteration 300 / 1200: loss 2.303171
# iteration 400 / 1200: loss 2.303151
# iteration 500 / 1200: loss 2.303111
# iteration 600 / 1200: loss 2.303033
# iteration 700 / 1200: loss 2.302948
# iteration 800 / 1200: loss 2.302970
# iteration 900 / 1200: loss 2.302821
# iteration 1000 / 1200: loss 2.302809
# iteration 1100 / 1200: loss 2.302674
# 225
# iteration 0 / 1400: loss 2.303249
# iteration 100 / 1400: loss 2.303201
# iteration 200 / 1400: loss 2.303183
# iteration 300 / 1400: loss 2.303128
# iteration 400 / 1400: loss 2.303058
# iteration 500 / 1400: loss 2.303120
# iteration 600 / 1400: loss 2.303064
# iteration 700 / 1400: loss 2.302980
# iteration 800 / 1400: loss 2.302909
# iteration 900 / 1400: loss 2.302855
# iteration 1000 / 1400: loss 2.302676
# iteration 1100 / 1400: loss 2.302685
# iteration 1200 / 1400: loss 2.302494
# iteration 1300 / 1400: loss 2.302210
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f5ff8c42e4e1> in <module>()
#      49     train_acc, val_acc = results[(lr, rs, hs, ni)]
#      50     print('lr %e rs %e hs %d ni %d train acc: %f val acc: %f' % (
# ---> 51                 hs, lr, reg, decay, train_acc, val_acc))
#      52 (best_net, best_val) = max(best, key=itemgetter(1))
#      53
#
# NameError: name 'reg' is not defined

# %%
# Print your validation accuracy: this should be above 48%
val_acc = (best_net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ffd8a1f20643> in <module>()
#       1 # Print your validation accuracy: this should be above 48%
# ----> 2 val_acc = (best_net.predict(X_val) == y_val).mean()
#       3 print('Validation accuracy: ', val_acc)
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %%
# Visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
# Print your test accuracy: this should be above 48%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.387

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$
#
# $\color{blue}{\textit Your Explanation:}$

# %% [markdown]
# ---
# # IMPORTANT
#
# This is the end of this question. Please do the following:
#
# 1. Click `File -> Save` to make sure the latest checkpoint of this notebook is saved to your Drive.
# 2. Execute the cell below to download the modified `.py` files back to your drive.

# %%
import os

FOLDER_TO_SAVE = os.path.join('drive/My Drive/', FOLDERNAME)
FILES_TO_SAVE = ['cs231n/classifiers/neural_net.py']

for files in FILES_TO_SAVE:
  with open(os.path.join(FOLDER_TO_SAVE, '/'.join(files.split('/')[1:])), 'w') as f:
    f.write(''.join(open(files).readlines()))
